# %% [markdown]
# # 01 | Simulação de Dados
#
# Executa a geração dos dados sintéticos da Aurora Finance Intelligence.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))
import pandas as pd
from src.simulate_data import execute
from src.config import RAW_CLIENTES, RAW_CATEGORIAS, RAW_TRANSACOES

# %%
execute()

# %%
display(pd.read_csv(RAW_CLIENTES).head())
display(pd.read_csv(RAW_CATEGORIAS))
display(pd.read_csv(RAW_TRANSACOES).head())
