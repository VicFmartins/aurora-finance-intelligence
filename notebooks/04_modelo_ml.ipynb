# %% [markdown]
# # 04 | Modelo ML
#
# Treinamento do modelo de churn, geração de métricas e export de predições.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))
import json
import pandas as pd
from src.train_model import execute as train_execute
from src.export_frontend_data import execute as export_execute
from src.config import MODEL_METRICS_FILE, FEATURE_IMPORTANCE_FILE, PREDICTIONS_FILE

# %%
train_execute()
export_execute()

# %%
display(pd.read_csv(PREDICTIONS_FILE).head(10))
display(pd.read_csv(FEATURE_IMPORTANCE_FILE).head(10))
json.loads(Path(MODEL_METRICS_FILE).read_text(encoding='utf-8'))
